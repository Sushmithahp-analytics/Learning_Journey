# %%
"""1. E-commerce Discount Calculator
Scenario: An online store offers discounts based on the purchase amount:
10% discount for purchases between $100 and $500
20% discount for purchases above $500
No discount for purchases below $100
Task: Write a program that takes the purchase amount as input and calculates the discount and final amount to be paid.
"""
p_amount = int(input("enter purchase amount :"))
if p_amount>0 and p_amount<100:
    print("no discount")
    b_amount = p_amount
    discount = 0
elif p_amount>=100 and p_amount<=500:
    print("10% discount")
    discount = p_amount * 0.1
    b_amount=p_amount-discount
elif p_amount> 500:
    print("20% discount")
    discount = p_amount * 0.2
    b_amount=p_amount-discount
else:
    print("invalid amount")
    discount = "invalid"
    b_amount = "invalid"

print(f"purchase amount :{p_amount}\n discount amount :{discount}\n total bill amount :{b_amount}")
# Out:
# enter purchase amount : 697
# 20% discount
# purchase amount :697
#  discount amount :139.4
#  total bill amount :557.6

# %%
"""2. Traffic Light Simulation
Scenario: Create a program that simulates a traffic light. The user inputs one of the colors: Red, Yellow, or Green. Based on the input:
If the input is Red, display "Stop."
If the input is Yellow, display "Ready to move."
If the input is Green, display "Go."
For invalid input, display "Invalid color." 
"""
color = input("enter the color :")
color = color.lower()
if color == "red":
    print("STOP")
elif color == "yellow":
    print("READY TO MOVE")
elif color == "green":
    print("GO")
else:
    print("Invalid Color")
# Out:
# enter the color : pink
# Invalid Color

# %%
"""3. Grade Evaluation System
Scenario: A school uses the following grading system:
Marks >= 90: Grade A
Marks >= 75 and < 90: Grade B
Marks >= 50 and < 75: Grade C
Marks < 50: Fail
Task: Write a program that accepts the student's marks and displays their grade 
"""
marks = float(input("enter the marks: "))
if (marks<0 or marks>100):
    print("invalid input")
elif (marks>=90):
    print("Grade A")
elif (marks >=75):
    print("Grade B")
elif (marks >=50):
    print("Grade C")
else:
   print("fail")
# Out:
# enter the marks:  56
# Grade C

# %%
"""4. Odd or Even and Divisibility Check
Scenario: Write a program that takes an integer as input and checks:
Whether the number is odd or even
Whether the number is divisible by 5
Display appropriate messages for both conditions.
"""
n = int(input("enter a number :"))
if (n%2 ==0):
       print(n,"is even number")
else:
    print(n,"is odd number") 
if (n%5 ==0):
        print(n,"is divisible by 5") 
else:
    print(n,"is not divisible by 5")
# Out:
# enter a number : 10
# 10 is even number
# 10 is divisible by 5

# %%
"""5. Password Strength Checker
Scenario: Write a program that checks the strength of a password based on these rules:
Length >= 8 characters: Strong
Length between 5 and 7 characters: Medium
Length < 5 characters: Weak
"""
password = input("enter a password:")
if len(password)>=8:
    print("Strong Password ")
elif len(password)>=5 and len(password)<=7:
    print("Medium Password ")
else:
    print("Weak Password")
# Out:
# enter a password: 87hn76^&$
# Strong Password

# %%
"""6. Electricity Bill Calculator
Scenario: An electricity company charges its customers as follows:
First 100 units: $0.5 per unit
Next 100 units (101-200): $0.75 per unit
Above 200 units: $1 per unit
Task: Write a program that accepts the number of units consumed and calculates the total bill.
"""
units = int(input("Enter electricity units consumed: "))
if units <= 100:
    bill = units*0.5
elif units <= 200:
    bill = (100*0.5) + ((units-100)*0.75)
else:
    bill = (100*0.5) + (100*0.75)+((units - 200)*1)
print(f"Total electricity bill: ${bill}")
# Out:
# Enter electricity units consumed:  156
# Total electricity bill: $92.0

# %%
"""7. Eligibility for Loan Approval
Scenario: A bank approves loans based on these conditions:
Age should be between 21 and 60
Monthly income should be greater than or equal to $5000
Task: Write a program to check whether a person is eligible for the loan based on their age and monthly income.
"""
age = int(input("enter age of the person:"))
m_income = int(input("enter monthly income of the person:"))
if (age<21) or (age>60):
    print("not elegible for loan approval")
elif (m_income>=5000):
        print("eligible for loan approval")
else:
    print("not elegible for loan approval")
# Out:
# enter age of the person: 26
# enter monthly income of the person: 9000
# eligible for loan approval

# %%
"""8. Temperature Alert System
Scenario: A weather monitoring system alerts based on the temperature:
Below 0°C: "Freezing weather"
0°C to 20°C: "Cold weather"
21°C to 30°C: "Warm weather"
Above 30°C: "Hot weather"
Task: Write a program that takes the temperature as input and displays the corresponding alert message
"""
temp = int(input("enter temperature: "))
if (temp>30):
    print("Hot weather")
elif (temp>=21):
    print("Warm weather")
elif (temp >=0):
    print("Cold weather")
else:
   print("Freezing weather")
# Out:
# enter temperature:  -9
# Freezing weather

# %%
"""1. Grading System
Write a Python program that takes a student’s marks as input.
If marks ≥ 90 → print "Grade A"
Else if marks ≥ 75 → print "Grade B"
Else if marks ≥ 50 → print "Grade C"
Else → print "Fail" 
"""
marks = float(input("enter the marks: "))
if (marks>=0 and marks<=100):
    if (marks>=90):
        print("Grade A")
    elif (marks >=75):
        print("Grade B")
    elif (marks >=50):
        print("Grade C")
    else:
       print("fail")
else:
    print("invalid input")
# Out:
# enter the marks:  -9
# invalid input

# %%
"""2. ATM Withdrawal Check
Ask the user for:
Account balance
Amount to withdraw
Check using nested if:
If balance ≥ withdrawal amount → further check if withdrawal amount is a multiple of 100
If yes → "Transaction Successful"
Else → "Enter amount in multiples of 100"
Else → "Insufficient Balance"
"""
balance=float(input("enter balance amount :"))
w_amount= float(input("enter withdrawal amount :"))
if (balance>=w_amount):
    if(w_amount%100==0):
        print("transaction successful")
    else:
        print("please enter the amount in multiples of hundred ")
else:
    print("insufficient balance")
# Out:
# enter balance amount : 4566.90
# enter withdrawal amount : 4500
# transaction successful

# %%
"""3. Triangle Type Checker
Take three sides of a triangle as input.
First check if it forms a valid triangle (a+b > c, b+c > a, a+c > b).
If valid, then check:
If all sides are equal → "Equilateral"
Else if two sides are equal → "Isosceles"
Else → "Scalene"
Else → "Not a Triangle" 
"""
a= float(input("enter side a value:"))
b= float(input("enter side b value:"))
c= float(input("enter side c value:"))

if((a+b)>c and (a+c)>b and (b+c)>a):
    if (a==b==c):
        print("it is equilateral triangle")
    elif ((a==b) or(a==c) or (b==c)):
        print("it is isosceles triangle")
    else:
        print("it is scalene triangle")
else:
    print("Not a triangle")
# Out:
# enter side a value: 1
# enter side b value: 2
# enter side c value: 3
# Not a triangle

# %%
"""4. Voting Eligibility
Ask the user for age and citizenship (Indian/Other).
If age ≥ 18
If citizenship is Indian → "Eligible to Vote"
Else → "Not Eligible (Non-Citizen)"
Else → "Not Eligible (Underage)" 
"""
age = int(input("enter the age of the person :"))
citizenship = input("enter the citizenship of the person :")
citizenship =citizenship.lower()
if (age>=18):
    if (citizenship =="indian"):
        print("the person is elegible for voting")
    else:
        print("the person is not elegible for voting(Non-Citizen)")
else:
    print("the person is not elegible for voting(Underage)")
# Out:
# enter the age of the person : 45
# enter the citizenship of the person : usa
# the person is not elegible for voting(Non-Citizen)

# %%
"""5. Discount Calculator
Take the total bill amount as input.
If bill ≥ 5000
If bill ≥ 10000 → give 20% discount
Else → give 10% discount
Else
If bill ≥ 2000 → give 5% discount
Else → "No Discount"
"""
p_amount = int(input("Enter purchase amount: "))
if p_amount >= 5000:
    if p_amount >= 10000:
        print("20% discount")
        discount = p_amount * 0.20
    else:
        print("10% discount")
        discount = p_amount*0.10
elif p_amount >= 2000:
    print("5% discount")
    discount = p_amount*0.05
else:
    print("No discount")
    discount = 0
b_amount = p_amount-discount
print(f"""
Purchase amount : {p_amount}
Discount amount : {discount}
Total bill amount : {b_amount}
""")
# Out:
# enter purchase amount : 5000
# 10% discount
# purchase amount :5000
#  discount amount :250.0
#  total bill amount :4750.0
